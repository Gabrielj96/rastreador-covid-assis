# %% [markdown]
# ## Importando Dados e Bibliotecas

# %%
import pandas as pd
import requests, json
import gspread
from df2gspread import df2gspread as d2g
from oauth2client.service_account import ServiceAccountCredentials
from gspread_formatting import *
import urllib.request, urllib.parse, urllib.error

request = requests.get("https://brasil.io/api/dataset/covid19/caso_full/data?city=Assis")

# %%
data_json = json.loads(request.content)
data = pd.DataFrame.from_dict(data_json['results'], orient='columns')
data
# Out:
#      city  city_ibge_code        date  epidemiological_week  \
# 0   Assis         3504008  2020-07-01                    27
# 1   Assis         3504008  2020-06-30                    27
# 2   Assis         3504008  2020-06-29                    27
# 3   Assis         3504008  2020-06-28                    27
# 4   Assis         3504008  2020-06-27                    26
# ..    ...             ...         ...                   ...
# 86  Assis         3504008  2020-04-06                    15
# 87  Assis         3504008  2020-04-05                    15
# 88  Assis         3504008  2020-04-04                    14
# 89  Assis         3504008  2020-04-03                    14
# 90  Assis         3504008  2020-04-02                    14
#
#     estimated_population_2019  is_last  is_repeated  last_available_confirmed  \
# 0                      104386    False         True                       182
# 1                      104386     True        False                       182
# 2                      104386    False        False                       173
# 3                      104386    False        False                       171
# 4                      104386    False        False                       169
# ..                        ...      ...          ...                       ...
# 86                     104386    False        False                         1
# 87                     104386    False        False                         1
# 88                     104386    False        False                         1
# 89                     104386    False        False                         1
# 90                     104386    False        False                         1
#
#     last_available_confirmed_per_100k_inhabitants last_available_date  \
# 0                                       174.35288          2020-06-30
# 1                                       174.35288          2020-06-30
# 2                                       165.73104          2020-06-29
# 3                                       163.81507          2020-06-28
# 4                                       161.89911          2020-06-27
# ..                                            ...                 ...
# 86                                        0.95798          2020-04-06
# 87                                        0.95798          2020-04-05
# 88                                        0.95798          2020-04-04
# 89                                        0.95798          2020-04-03
# 90                                        0.95798          2020-04-02
#
#     last_available_death_rate  last_available_deaths  new_confirmed  \
# 0                      0.0604                     11              0
# 1                      0.0604                     11              9
# 2                      0.0462                      8              2
# 3                      0.0468                      8              2
# 4                      0.0473                      8              2
# ..                        ...                    ...            ...
# 86                     0.0000                      0              0
# 87                     0.0000                      0              0
# 88                     0.0000                      0              0
# 89                     0.0000                      0              0
# 90                     0.0000                      0              1
#
#     new_deaths  order_for_place place_type state
# 0            0               91       city    SP
# 1            3               90       city    SP
# 2            0               89       city    SP
# 3            0               88       city    SP
# 4            0               87       city    SP
# ..         ...              ...        ...   ...
# 86           0                5       city    SP
# 87           0                4       city    SP
# 88           0                3       city    SP
# 89           0                2       city    SP
# 90           0                1       city    SP
#
# [91 rows x 17 columns]

# %%
url = "https://public.tableau.com/vizql/w/IsolamentoSocial/v/Dashboard/vudcsv/sessions/C79DEB28CCC04D6EB256BD57CDDC9644-0:0/views/3855800012607193825_2898247358194207686?summary=true"
urllib.request.urlretrieve(url, "isolamento-social-assis.csv")
isol = pd.read_csv("isolamento-social-assis.csv", delimiter=';')
isol
# Out:
#                      Data            DIA Média de Índice De Isolamento
# 0     quinta-feira, 05/03   Quinta-feira                           36%
# 1      sexta-feira, 06/03    Sexta-feira                           34%
# 2     quinta-feira, 12/03   Quinta-feira                           31%
# 3      sexta-feira, 13/03    Sexta-feira                           34%
# 4      terça-feira, 17/03    Terça-feira                           40%
# ..                    ...            ...                           ...
# 105    sexta-feira, 26/06    Sexta-feira                           40%
# 106         sábado, 27/06         Sábado                           44%
# 107        domingo, 28/06        Domingo                           48%
# 108  segunda-feira, 29/06  Segunda-feira                           41%
# 109    terça-feira, 30/06    Terça-feira                           42%
#
# [110 rows x 3 columns]

# %% [markdown]
# ## Limpando Dados

# %%
data['last_available_confirmed_per_100k_inhabitants'] = data['last_available_confirmed_per_100k_inhabitants'].astype(str).str.split('.', expand=True)[0]

# %%
columns_to_drop = ['city_ibge_code', 'estimated_population_2019', 'last_available_date', 'is_repeated',
                   'is_last', 'place_type', 'state', 'is_repeated', 'order_for_place', 'state']

# %%
data = data.drop(columns=columns_to_drop)

# %%
data['last_available_death_rate'] = data['last_available_death_rate'] * 100
data['last_available_death_rate'] = data['last_available_death_rate'].round(2)

# %%
data
# Out:
#      city        date  epidemiological_week  last_available_confirmed  \
# 0   Assis  2020-07-01                    27                       182
# 1   Assis  2020-06-30                    27                       182
# 2   Assis  2020-06-29                    27                       173
# 3   Assis  2020-06-28                    27                       171
# 4   Assis  2020-06-27                    26                       169
# ..    ...         ...                   ...                       ...
# 86  Assis  2020-04-06                    15                         1
# 87  Assis  2020-04-05                    15                         1
# 88  Assis  2020-04-04                    14                         1
# 89  Assis  2020-04-03                    14                         1
# 90  Assis  2020-04-02                    14                         1
#
#    last_available_confirmed_per_100k_inhabitants  last_available_death_rate  \
# 0                                            174                       6.04
# 1                                            174                       6.04
# 2                                            165                       4.62
# 3                                            163                       4.68
# 4                                            161                       4.73
# ..                                           ...                        ...
# 86                                             0                       0.00
# 87                                             0                       0.00
# 88                                             0                       0.00
# 89                                             0                       0.00
# 90                                             0                       0.00
#
#     last_available_deaths  new_confirmed  new_deaths
# 0                      11              0           0
# 1                      11              9           3
# 2                       8              2           0
# 3                       8              2           0
# 4                       8              2           0
# ..                    ...            ...         ...
# 86                      0              0           0
# 87                      0              0           0
# 88                      0              0           0
# 89                      0              0           0
# 90                      0              1           0
#
# [91 rows x 9 columns]

# %%
isol['Data'] = isol['Data'].str.split(',', expand=True)[1]
isol = isol.drop(columns='DIA')
isol
# Out:
#        Data Média de Índice De Isolamento
# 0     05/03                           36%
# 1     06/03                           34%
# 2     12/03                           31%
# 3     13/03                           34%
# 4     17/03                           40%
# ..      ...                           ...
# 105   26/06                           40%
# 106   27/06                           44%
# 107   28/06                           48%
# 108   29/06                           41%
# 109   30/06                           42%
#
# [110 rows x 2 columns]

# %% [markdown]
# ## Conectando ao Google Spreadsheet e Enviando Dados

# %%
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

credentials = ServiceAccountCredentials.from_json_keyfile_name(
    'covid19-assis.json', scopes=scope)

gc = gspread.authorize(credentials)

# %%
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from gspread_formatting.dataframe import format_with_dataframe, BasicFormatter

# %%
sheet = gc.open('Covid19 Assis')

# %%
set_with_dataframe(sheet.sheet1, data)

# %%
set_with_dataframe(sheet.get_worksheet(1), isol)
